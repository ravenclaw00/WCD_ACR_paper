# %%
import xarray as xr
import os as os
import pandas as pd
from netCDF4 import Dataset as NetCDFFile 
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap

path = "N:/atm_glomod/user/jomuel001/aacrm21_jja.nc"

fig = plt.figure(figsize=(8, 8))
#map = Basemap(projection='ortho',lat_0=90, lon_0=360)
nc = NetCDFFile(path+path_file)
#print(nc)
#nc

lat = nc.variables['psl'][:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1584\411134622.py in <cell line: 0>()
# ----> 1 import xarray as xr
#       2 import os as os
#       3 import pandas as pd
#       4 from netCDF4 import Dataset as NetCDFFile
#       5 import matplotlib.pyplot as plt
#
# ~\WPy64-31101\python-3.11.0.amd64\Lib\site-packages\xarray\__init__.py in <module>
# ----> 1 from . import testing, tutorial
#       2 from .backends.api import (
#       3     load_dataarray,
#       4     load_dataset,
#       5     open_dataarray,
#
# ~\WPy64-31101\python-3.11.0.amd64\Lib\site-packages\xarray\testing.py in <module>
#       7 import pandas as pd
#       8
# ----> 9 from xarray.core import duck_array_ops, formatting, utils
#      10 from xarray.core.dataarray import DataArray
#      11 from xarray.core.dataset import Dataset
#
# ...
