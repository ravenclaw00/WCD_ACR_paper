# %% [markdown]
# # Auswertung Arktis barplots
# ## Sommer (JJAS)

# %% [markdown]
# ### Pacific

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
path = r"N:\atm_glomod\user\jomuel001\CMIP6_models"
zusatz = r"AREA.90_270_89.7849_29.0866\CLUSTER\PLOTS"
datei = r"KMEANSslp_unnorm_5cluster_bar_plot_10PC_high_low.txt"
models = ["ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
         "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","ERA5","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
         "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
          "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
#models = ["r10i1p1f1","r15i1p1f1","r1i1p1f1","r23i1p1f1","r28i1p1f1","r4i1p1f1","r9i1p1f1","r11i1p1f1","r16i1p1f1",
    #      "r1i2000p1f1","r24i1p1f1","r29i1p1f1","r5i1p1f1","r12i1p1f1","r17i1p1f1","r20i1p1f1","r25i1p1f1","r2i1p1f1",
     #     "r6i1p1f1","r13i1p1f1","r18i1p1f1","r21i1p1f1","r26i1p1f1","r30i1p1f1","r7i1p1f1","r14i1p1f1","r19i1p1f1",
      #    "r22i1p1f1","r27i1p1f1","r3i1p1f1","r8i1p1f1"]
#models = ["ACCESS-CM2","ACCESS-ESM1"]

# %%
length=len(models)
data_all=np.zeros((length,2,5))
#path_model=path+"\\"+models[0]+"\\"+zusatz+"\\"+datei
#print(data_all)
def data_definition(models):
    path_model= path+"\\"+models+"\\"+zusatz+"\\"+datei
    data = np.loadtxt(path_model, delimiter=' ', skiprows=1, usecols=range(1,6))
    return data
for i in range(length):
    data_all[i,:,:]=data_definition(models[i])
    
#data_all[i,:,:] enthält infos über modell i, modell i ist in models liste zu entnehmen
# data_all[i,0,:] ist high ice data von modell i 
#data_all [i,1,:] ist low ice data von modell i
#data_all

# %%
#high_ice=data_all[i,0,:]
#low_ice=data[i,1,:]
x_data=np.array([1,2,3,4,5])

# %%
for i in range(length):
    plt.title(str(models[i]))
    if models[i] == 'ERA5':
        plt.bar(x_data, data_all[i,0,:], width=-0.25,color='blue',align='edge',edgecolor="darkblue",label='high ice (1979-1996)')
        plt.bar(x_data+0.28, data_all[i,1,:], width=-0.25,color='red',align='edge',edgecolor="darkred",label='low ice (1997-2014)')
    else:
        plt.bar(x_data, data_all[i,0,:], width=-0.25,color='blue',align='edge',edgecolor="darkblue",label='high ice (1979-1996)')
        plt.bar(x_data+0.28, data_all[i,1,:], width=-0.25,color='red',align='edge',edgecolor="darkred",label='low ice (1997-2014)')
    plt.xlabel("cluster pattern")
    plt.ylabel("chance of pattern / day")
    #plt.text(1,-0.05,"chance of pattern / day : day mean")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Atlantic

# %%
zusatz = r"AREA.-90_90_89.7849_29.0866\CLUSTER\PLOTS"
datei = r"KMEANSslp_unnorm_5cluster_bar_plot_5PC_high_low.txt"
models = ["ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
         "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","ERA5","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
         "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
          "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
length=len(models)
data_all=np.zeros((length,2,5))
#path_model=path+"\\"+models[0]+"\\"+zusatz+"\\"+datei
#print(data_all)
def data_definition(models):
    path_model= path+"\\"+models+"\\"+zusatz+"\\"+datei
    data = np.loadtxt(path_model, delimiter=' ', skiprows=1, usecols=range(1,6))
    return data
for i in range(length):
    data_all[i,:,:]=data_definition(models[i])
    
#data_all[i,:,:] enthält infos über modell i, modell i ist in models liste zu entnehmen
# data_all[i,0,:] ist high ice data von modell i 
#data_all [i,1,:] ist low ice data von modell i
#data_all
x_data=np.array([1,2,3,4,5])

# %%
zusatz = r"AREA.90_270_89.7849_29.0866\CLUSTER\PLOTS"
for i in range(length):
    plt.title(str(models[i]))
    if models[i] == 'ERA5':
        plt.bar(x_data, data_all[i,0,:], width=-0.25,color='blue',align='edge',edgecolor="darkblue",label='high ice (1979-1996)')
        plt.bar(x_data+0.28, data_all[i,1,:], width=-0.25,color='red',align='edge',edgecolor="darkred",label='low ice (1997-2014)')
    else:
        plt.bar(x_data, data_all[i,0,:], width=-0.25,color='blue',align='edge',edgecolor="darkblue",label='high ice (1979-1996)')
        plt.bar(x_data+0.28, data_all[i,1,:], width=-0.25,color='red',align='edge',edgecolor="darkred",label='low ice (1997-2014)')
    plt.xlabel("cluster pattern")
    plt.ylabel("chance of pattern / day")
    #plt.text(1,-0.05,"chance of pattern / day : day mean")
    plt.legend()
    plt.savefig(path+"\\"+models[i]+"\\"+zusatz+"\\"+models[i]+".png")
    plt.show()

# %% [markdown]
# # Bootstrap significance

# %% [markdown]
# ## TAYLOR diagramme

# %% [markdown]
# ### Pacific

# %% [markdown]
# ### how to select the cluster pattern: the pattern with highest correlation

# %% [markdown]
# example

# %%
path_taylor_select = r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Clusternumber-2/taylor_cluster_polex.slp_jjas.cl2_paz.refERA5"
add = models[0]
data_taylor = np.loadtxt(path_taylor_select+add+".txt", skiprows = 2, usecols = range(1,5))
std = data_taylor[:,0]
cor = data_taylor[:,1]
score1 = data_taylor[:,2]
print(models[0], 'CLusternummer ',max(cor))
models_taylor = ["ERA5", models[0]+str(1), models[0]+str(2), models[0]+str(3), models[0]+str(4), models[0]+str(5)]
import skill_metrics as sm
sm.taylor_diagram(std, score1, cor, titleOBS = 'Ref',colobs = 'k',markerlabel=models_taylor,markerlegend='on' ,markerobs='x', 
                  markersize = 10, titleobs= 'ERA5', markercolor='r',widthcor= 0.5,widthobs=0.3, widthrms=0.3,widthstd =0.8,
                  styleobs='--',titlerms='off')
plt.savefig("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Clusternumber-2/Taylor_Diagram_example.png",dpi=300,bbox_inches='tight')
# Out:
# ACCESS-CM2 CLusternummer  1.0

# %% [markdown]
# now, let computer do the work

# %% [markdown]
# #### Clusternumber 2

# %% [markdown]
# # Taylor Diagram erstellen Vorlage Sommer

# %%
#models = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
   #      "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
    #     "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
     #     "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
import glob
models = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1",
          "GFDL-CM4","GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
         "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","MULTIMODEL-hist"]
models_taylor = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR",
          "CNRM-ESM2-1","GFDL-CM4", "GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
         "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","common \n analysis"]
seas="mjjaso"
namen="naominus"
assigner = 3 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "atl"
cluster="*"
zusatz="historical1985-2014"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5ACCESS-CM2.txt")
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
cl = {'models' : ["cor", "std", "score1"],
            models[0]: [1, std_ERA/std_ERA, 1],
            models[1]: [0, 1, 2],
            models[2]:[0, 1, 2],
            models[3]: [0, 1, 2],
            models[4]: [0, 1, 2],
            models[5]: [0, 1, 2],
            models[6]: [0, 1, 2],
            models[7]: [0, 1, 2],
            models[8]: [0, 1, 2],
            models[9]: [0, 1, 2],
            models[10]: [0, 1, 2],
            models[11]: [0, 1, 2],
            models[12]: [0, 1, 2],
            models[13]: [0, 1, 2],
            models[14]: [0, 1, 2],
            models[15]: [0, 1, 2],
            models[16]: [0, 1, 2],
            models[17]: [0, 1, 2],
            models[18]: [0, 1, 2]}
for i in range(len(models)):
    if models[i]=="ERA5":
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_"+area+"_"+zusatz+"_"+seas+".txt", skiprows=1)[i-1,:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models[i]]=[cor[index], std[index], score1[index]]
cl = pd.DataFrame(cl).transpose() 
#print(cl)

#models_taylor = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
     #    "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
      #   "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
       #   "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
std = np.array(list(cl[1][1:]))
cor = np.array(list(cl[0][1:]))
score1 = np.array(list(cl[2][1:]))

import skill_metrics as sm
color="g"
color2="g"
MARKERS = {
    models[1]: { "labelColor": "k", "symbol": "+", "size": 0, "faceColor": color, "edgeColor": color,},
   models[2]: { "labelColor": "k", "symbol": "*", "size": 0, "faceColor": color, "edgeColor": color,},
     models[3]: { "labelColor": "k", "symbol": "v", "size": 0, "faceColor": color, "edgeColor": color,},
     models[4]: { "labelColor": "k", "symbol": "s", "size": 0, "faceColor": color, "edgeColor": color,},
     models[5]: { "labelColor": "k", "symbol": "<", "size": 0, "faceColor": color, "edgeColor": color,},
    models[6]: { "labelColor": "k", "symbol": ">", "size": 0, "faceColor": color2, "edgeColor": color2,},
     models[7]: { "labelColor": "k", "symbol": "^", "size": 0, "faceColor": color, "edgeColor": color,},
     models[8]: { "labelColor": "k", "symbol": "o", "size": 0, "faceColor": color, "edgeColor": color,},
    models[9]: { "labelColor": "k", "symbol": "p", "size": 0, "faceColor": color, "edgeColor": color,},
     models[10]: { "labelColor": "k", "symbol": "8", "size": 0, "faceColor": color, "edgeColor": color,},
    models[11]: { "labelColor": "k", "symbol": "P", "size": 0, "faceColor": color, "edgeColor": color,},
     models[12]: { "labelColor": "k", "symbol": "h", "size": 0, "faceColor": color, "edgeColor": color,},
     models[13]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color2, "edgeColor": color2,},
    models[14]: { "labelColor": "k", "symbol": "*", "size": 9, "faceColor": color, "edgeColor": color,},
    models[15]: { "labelColor": "k", "symbol": "+", "size": 9, "faceColor":color, "edgeColor": color,},
    models[16]: { "labelColor": "k", "symbol": "s", "size": 9, "faceColor": color, "edgeColor": color,},
    models[17]: { "labelColor": "k", "symbol": "1", "size": 0, "faceColor": color2, "edgeColor": color2,},
    models[18]: { "labelColor": "k", "symbol": "2", "size": 0, "faceColor": color, "edgeColor": color,},
    models_taylor[19]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": "k", "edgeColor": "k",}
}
sm.taylor_diagram(std, score1, cor, titleOBS='Ref', colobs='k', markerlabel=models_taylor, markerlegend='on', 
                  markerobs='X', markersize=15, titleobs='CMIP6 model historical as reference     .      .        .', widthcor=0.5, widthobs=0.3, widthrms=0.3, 
                  widthstd=0.8, styleobs='--', titlerms='off', colRMS='grey', colCOR='black',markers=MARKERS,numberPanels=1)

plt.savefig('N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/'+namen+'/Vortrag_Taylor_Diagram_'+seas+"_"+zusatz+'_10PC_cl.png',dpi=300,bbox_inches='tight')
#plt.savefig('N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/'+namen+'/Taylor_Diagram_'+seas+"_"+zusatz+'_10PC_cl_POLARRES.png',dpi=300,bbox_inches='tight')
# Out:
# ERA5 u need to choose yourself

# %%
print(sm.taylor_diagram())
# Out:
# None

# %% [markdown]
# ## Ranking of models

# %%
import glob
models = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1", 
         "GFDL-CM4", "GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
         "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","MULTIMODEL-hist"]
models_taylor = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1", 
         "GFDL-CM4", "GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
         "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","common-analysis"]
seas="mjjaso"
namen="Clusternumber-5"
assigner = 5 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "paz"
cluster="*"
zusatz="historical1985-2014"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5ACCESS-CM2.txt")
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
cl = {'models' : ["cor", "std", "score1"],
            models[0]: [1, std_ERA/std_ERA, 1],
            models[1]: [0, 1, 2],
            models[2]:[0, 1, 2],
            models[3]: [0, 1, 2],
            models[4]: [0, 1, 2],
            models[5]: [0, 1, 2],
            models[6]: [0, 1, 2],
            models[7]: [0, 1, 2],
            models[8]: [0, 1, 2],
            models[9]: [0, 1, 2],
            models[10]: [0, 1, 2],
            models[11]: [0, 1, 2],
            models[12]: [0, 1, 2],
            models[13]: [0, 1, 2],
            models[14]: [0, 1, 2],
            models[15]: [0, 1, 2],
            models[16]: [0, 1, 2],
            models[17]: [0, 1, 2]}
for i in range(len(models)):
    if models[i]=="ERA5":
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_"+area+"_"+zusatz+"_"+seas+".txt", skiprows=1)[i-1,:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models[i]]=[cor[index], std[index], score1[index]]
cl = pd.DataFrame(cl).transpose() 
#print(cl)

#models_taylor = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
     #    "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
      #   "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
       #   "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
std = np.array(list(cl[1][1:]))
cor = np.array(list(cl[0][1:]))
score1 = np.array(list(cl[2][1:]))
# if namen=="DipolATLBlock":
#     cor_dipol=cor
# elif namen=="SCANURALBlock":
#     cor_scan=cor
# elif namen=="NAOPlus":
#     cor_naoPlus=cor
# elif namen=="NAOMinus":
#     cor_naominus=cor
# else: 
#     cor_atl=cor
if namen=="Clusternumber-1":
    cor_c1=cor
elif namen=="Clusternumber-2":
    cor_c2=cor
elif namen=="Clusternumber-3":
    cor_c3=cor
elif namen=="Clusternumber-4":
    cor_c4=cor
else: 
    cor_c5=cor
# Out:
# ERA5 u need to choose yourself

# %%
summe= cor_dipol+cor_scan+cor_naoPlus+cor_naominus+cor_atl

summe_paz=cor_c1 + cor_c2 + cor_c3 + cor_c4 + cor_c5
my_dict = {key: value for key, value in zip(models, summe)}
my_dict2 = {key: value for key, value in zip(models, summe_paz)}
df_ = pd.DataFrame(list(my_dict.items()), columns=['Key', 'Value'])
df_2 = pd.DataFrame(list(my_dict2.items()), columns=['Key2', 'Value2'])
#df_beide = pd.DataFrame(list(my_dict.items()), columns=['Key2', 'Value2'])
combined_df = pd.concat((df_,df_2),axis=1)
combined_df = combined_df.rename(columns={'Value': 'Atlantic'})
combined_df = combined_df.rename(columns={'Key': ' CMIP6 Model'})
combined_df = combined_df.rename(columns={'Value2': 'Pacific'})
#combined_df = combined_df.rename(columns={'Key3': 'DJFM'})
#combined_df = combined_df.drop('Value3', axis=1)
combined_df = combined_df.drop('Key2', axis=1)
list_row = ["Multi-Model Mean",combined_df['Atlantic'].mean() ,combined_df['Pacific'].mean()]
print(combined_df['Atlantic'].std())
print(combined_df['Pacific'].std())
combined_df.loc[len(combined_df)] = list_row
combined_df[' CMIP6 Model'][19]="common-analysis"
print(combined_df)
#combined_df = combined_df.drop(' CMIP6 Model', axis=1)
#combined_df = combined_df[[' CMIP6 Model','Atlantic']][1:]
#combined_df = combined_df[[' CMIP6 Model','Pacific']][2:]
format_floats = lambda x: '{:.2f}'.format(x) if isinstance(x, float) else x
combined_df = combined_df.applymap(format_floats)
#print(combined_df['DJFM'])
styled_df = combined_df[1:].style.background_gradient(subset=['Atlantic'],cmap='RdYlGn')
styled_df = styled_df.background_gradient(subset=['Pacific'],cmap='RdYlGn')
#styled_df = styled_df.background_gradient(subset=['Combined'],cmap='RdYlGn')

# Display the styled dataframe
display(styled_df)
styled_df.to_latex("N:/atm_glomod/user/jomuel001/Dokumente/MasterThesis/figures/sample/modelsevaluation.tex",convert_css=True)
#combined_df.to_pdf('N:/atm_glomod/user/jomuel001/Dokumente/Vortrag/atmoseminar/my_dataframe.pdf')
# Out:
# 0.4663265486759252
# 0.4864083485909216
#          CMIP6 Model  Atlantic  Pacific
# 0               ERA5   5.00000  5.00000
# 1         ACCESS-CM2   4.20400  3.35200
# 2        ACCESS-ESM1   3.68500  4.07800
# 3        CESM2-WACCM   3.58200  3.64500
# 4         CNRM-CM6-1   3.67300  3.89000
# 5      CNRM-CM6-1-HR   4.11800  3.41800
# 6        CNRM-ESM2-1   3.17600  4.00900
# 7           GFDL-CM4   4.38000  3.35100
# 8          GFDL-ESM4   3.94800  4.16200
# 9    HadGEM3-GC31-LL   3.41300  3.68900
# 10         INM-CM4-8   3.88000  3.33900
# 11         INM-CM5-0   4.13200  4.25900
# 12      IPSL-CM6A-LR   4.43100  3.08700
# 13            MIROC6   4.71100  4.44400
# 14     MPI-ESM1-2-HR   4.09900  3.67500
# 15     MPI-ESM1-2-LR   4.69500  3.95700
# 16        MRI-ESM2-0   3.73900  4.11200
# 17        NorESM2-MM   4.07700  4.40500
# 18       UKESM1-0-LL   3.55500  4.59400
# 19   common-analysis   4.25500  3.94100
# 20  Multi-Model Mean   4.03765  3.92035
# ...

# %% [markdown]
# ### SELF TAylor diagram

# %%
#models = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
   #      "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
    #     "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
     #     "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
import glob
models = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1", 
          "GFDL-ESM4", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6",  "MPI-ESM1-2-LR", "MRI-ESM2-0", "UKESM1-0-LL"]
models_taylor = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1", 
          "GFDL-ESM4", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6",  "MPI-ESM1-2-LR", "MRI-ESM2-0", "UKESM1-0-LL"]
seas="mjjaso"
namen="DipolATLBlock"
assigner = 24232 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5
area = "atl"
cluster="*"
zusatz="future2070-2099"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5ACCESS-CM2.txt")
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
cl = {'models' : ["cor", "std", "score1"],
            models[0]: [1, std_ERA/std_ERA, 1],
            models[1]: [0, 1, 2],
            models[2]:[0, 1, 2],
            models[3]: [0, 1, 2],
            models[4]: [0, 1, 2],
            models[5]: [0, 1, 2],
            models[6]: [0, 1, 2],
            models[7]: [0, 1, 2],
            models[8]: [0, 1, 2],
            models[9]: [0, 1, 2],
            models[10]: [0, 1, 2],
            models[11]: [0, 1, 2],
            models[12]: [0, 1, 2],
            models[13]: [0, 1, 2]}
            #models[14]: [0, 1, 2],
           # models[15]: [0, 1, 2],
          #  models[16]: [0, 1, 2],
         #   models[17]: [0, 1, 2]}
for i in range(len(models)):
    if models[i]=="ERA5":
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        #assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_"+area+"_"+zusatz+"_"+seas+".txt", skiprows=1)[i-1,:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)     
        #print(cor[1:])#   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = np.argmax(cor[1:])+1
        #print(index)
        cl[models[i]]=[cor[index], std[index], score1[index]]
cl = pd.DataFrame(cl).transpose() 
#print(cl)

#models_taylor = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
     #    "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
      #   "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
       #   "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
std = np.array(list(cl[1][1:]))
cor = np.array(list(cl[0][1:]))
score1 = np.array(list(cl[2][1:]))

import skill_metrics as sm
color="m"
color1="b"
color2="g"
color3="c"
color4="m"
MARKERS = {
    models[1]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
   models[2]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
     models[3]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
     models[4]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
     models[5]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
    models[6]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
     models[7]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
     models[8]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
    models[9]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
     models[10]: { "labelColor": "k", "symbol": "d", "size": 0, "faceColor": color, "edgeColor": color,},
    models[11]: { "labelColor": "k", "symbol": "d", "size": 9, "faceColor": color, "edgeColor": color,},
     models[12]: { "labelColor": "k", "symbol": "d", "size":9, "faceColor": color, "edgeColor": color,},
     models[13]: { "labelColor": "k", "symbol": "d", "size": 9, "faceColor": color, "edgeColor": color,},
    models[14]: { "labelColor": "k", "symbol": "d", "size": 9, "faceColor": color, "edgeColor": color,}
    #models[15]: { "labelColor": "k", "symbol": "d", "size": 9, "faceColor": color, "edgeColor": color,}
   # models[16]: { "labelColor": "k", "symbol": "D", "size": 9, "faceColor": color, "edgeColor": color,},
  #  models[17]: { "labelColor": "k", "symbol": "1", "size": 9, "faceColor": color, "edgeColor": color,},
 #   models[18]: { "labelColor": "k", "symbol": "2", "size": 9, "faceColor": color, "edgeColor": color,}
}
sm.taylor_diagram(std, score1, cor, titleOBS='Ref', colobs='k', markerlabel=models_taylor, markerlegend='on', 
                  markerobs='x', markersize=10, titleobs='Hist', widthcor=0.5, widthobs=0.3, widthrms=0.3, 
                  widthstd=0.8, styleobs='--', titlerms='off', colRMS='grey', colCOR='black',markers=MARKERS,numberPanels=1)
#plt.savefig('N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/'+namen+'/Taylor_Diagram_'+seas+"_"+zusatz+'_10PC_cl.png',dpi=300,bbox_inches='tight')
plt.text(0.1,0.9,"CMIP6 models\n future, SSP X",fontsize=16)
plt.savefig('N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/'+namen+'/Taylor_Diagram_Vorlage.png',dpi=300,bbox_inches='tight')
# Out:
# ERA5 u need to choose yourself

# %%
models = ["ERA5","SANDRA"]
#models = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1", 
       #   "GFDL-ESM4", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6",  "MPI-ESM1-2-LR", "MRI-ESM2-0", "UKESM1-0-LL","MULTIMODEL-SSP3"]
def maximize_sum(array):
    array_0=array[0]
    array_1=array[1]
    array_2=array[2]
    array_3=array[3]
    array_4=array[4]
    #array_5=array[5]
    n=len(array_0)
    best=0
    best_indexes=0
    f=0
    for i in range(n):
        for k in range(n):
            if k==i:
                continue
            for l in range(n):
                if l==i:
                    continue
                elif l==k:
                    continue
                for p in range(n):
                    if p==i:
                        continue
                    elif p==l:
                        continue
                    elif p==k:
                        continue
                    for r in range(n):
                        if r==p:
                            continue
                        elif r==i:
                            continue
                        elif r==k:
                            continue
                        elif r==l:
                            continue
                   #     for s in range(n):
                    #        if s==r:
                     #           continue
                      #      elif s==p:
                       #         continue
                        #    elif s==i:
                         #       continue
                          #  elif s==k:
                           #     continue
                            #elif s==l:
                             #   continue
                        summe=array_0[i]+array_1[k]+array_2[l]+array_3[p]+array_4[r]
                        f+=1
                        if summe>best:
                            best_indexes=i, k, l, p, r
                            best=summe
                        
    return best_indexes
years="historical_mmm3_1985-2014"
seas="mjjaso"
area="arc"
data = {'CL1/SCAN': [],
        'CL2/ATL': [],
        'CL3/NAO+': [],
        'CL4/NAO-': [],
        'CL5/DIPOL': []}
      #  'CL6/': []}
for i in range(len(models)):
    if models[i]=="ERA5":
        print("choose yourself")
    else:
        path_taylor_select_cl1=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL1/taylor_cluster_"+years+".slp_"+seas+".cl1_"+area+".refERA5"
        data_taylor_cl1 = np.loadtxt(path_taylor_select_cl1+models[i]+".txt", skiprows = 2, usecols = range(1,5))
        cor_cl1 = data_taylor_cl1[1:,1]
        path_taylor_select_cl2=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL2/taylor_cluster_"+years+".slp_"+seas+".cl2_"+area+".refERA5"
        data_taylor_cl2 = np.loadtxt(path_taylor_select_cl2+models[i]+".txt", skiprows = 2, usecols = range(1,5))
        cor_cl2 = data_taylor_cl2[1:,1]
        path_taylor_select_cl3=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL3/taylor_cluster_"+years+".slp_"+seas+".cl3_"+area+".refERA5"
        data_taylor_cl3 = np.loadtxt(path_taylor_select_cl3+models[i]+".txt", skiprows = 2, usecols = range(1,5))
        cor_cl3 = data_taylor_cl3[1:,1]
        path_taylor_select_cl4=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL4/taylor_cluster_"+years+".slp_"+seas+".cl4_"+area+".refERA5"
        data_taylor_cl4 = np.loadtxt(path_taylor_select_cl4+models[i]+".txt", skiprows = 2, usecols = range(1,5))
        cor_cl4 = data_taylor_cl4[1:,1]
        path_taylor_select_cl5=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL5/taylor_cluster_"+years+".slp_"+seas+".cl5_"+area+".refERA5"
        data_taylor_cl5 = np.loadtxt(path_taylor_select_cl5+models[i]+".txt", skiprows = 2, usecols = range(1,5))
        cor_cl5 = data_taylor_cl5[1:,1]
     #   path_taylor_select_cl6=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL6/taylor_cluster_"+years+".slp_"+seas+".cl6_"+area+".refERA5"
      #  data_taylor_cl6 = np.loadtxt(path_taylor_select_cl6+models[i]+".txt", skiprows = 2, usecols = range(1,5))
       # cor_cl6 = data_taylor_cl6[1:,1]
        argmaxarray = [cor_cl1, cor_cl2, cor_cl3, cor_cl4, cor_cl5]#,cor_cl6]
        maximized_indexes = maximize_sum(argmaxarray)
        print(models[i]+"mit CL1/SCAN: "+ str(maximized_indexes[0]+1)+"     mit CL2/ATL: "+ str(maximized_indexes[1]+1)+"     mit CL3/NAO+: "+ str(maximized_indexes[2]+1)+"     mit CL4/NAO-: "+ str(maximized_indexes[3]+1)+"     mit CL5/DIPOL: "+ str(maximized_indexes[4]+1))#+"      mit CL6/: "+str(maximized_indexes[5]+1))
        data['CL1/SCAN'].append(maximized_indexes[0]+1)
        data['CL2/ATL'].append(maximized_indexes[1]+1)
        data['CL3/NAO+'].append(maximized_indexes[2]+1)
        data['CL4/NAO-'].append(maximized_indexes[3]+1)
        data['CL5/DIPOL'].append(maximized_indexes[4]+1)
     #   data['CL6/'].append(maximized_indexes[5]+1)
df = pd.DataFrame(data)
print(df)
# Save the DataFrame to a txt file
df.to_csv('N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_paper_'+area+"5_"+years+"_"+seas+'.txt', sep='\t', index=False)
# Out:
# choose yourself
# SANDRAmit CL1/SCAN: 3     mit CL2/ATL: 1     mit CL3/NAO+: 2     mit CL4/NAO-: 5     mit CL5/DIPOL: 4
#    CL1/SCAN  CL2/ATL  CL3/NAO+  CL4/NAO-  CL5/DIPOL
# 0         3        1         2         5          4

# %% [markdown]
# ## Taylor Diagram erstellen- Vorlage winter

# %%
argmaxarray
# Out:
# [array([ 0.807,  0.577,  0.087, -0.733, -0.482]),
#  array([ 0.297, -0.768,  0.019,  0.656, -0.299]),
#  array([-0.238,  0.606,  0.799, -0.528, -0.472]),
#  array([-0.258,  0.378, -0.591, -0.325,  0.769]),
#  array([-0.604, -0.722, -0.398,  0.855,  0.576])]

# %% [markdown]
# also zuerst die CLUSTERanalyse machen. Dann hat man die bilder und daten der ganzen models für 5 cluster die aber random zugeteilt sind. Jetzt gilt es die CLUSTEr einem weather regime zuzuordnen. Dabei vergleicht man bekannte Regime mit den Mustern mit ERA5, die dann als Vergleich zählen.
# Per Auge guckt man ERA5 und regime. Dann taylor_select.sh, taylor_cluster.historical.select.R ausführen für die hier unteren dinger.
# Danach taylor_cluster.historical.CMIP6.R  für taylor diagramme.

# %%
#
#models = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1", 
    #     "GFDL-CM4", "GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
     #    "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","MULTIMODEL-hist"]
#models = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1", 
       #   "GFDL-ESM4", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6",  "MPI-ESM1-2-LR", "MRI-ESM2-0", "UKESM1-0-LL","MULTIMODEL-SSP3"]
models = ["MULTIMODEL-hist",  "MULTIMODEL-SSP5"]
    
def maximize_sum(array):
    array_0=array[0]
    array_1=array[1]
    array_2=array[2]
    array_3=array[3]
    array_4=array[4]
    array_5=array[5]
    n=len(array_0)
    best=0
    best_indexes=0
    f=0
    for i in range(n):
        for k in range(n):
            if k==i:
                continue
            for l in range(n):
                if l==i:
                    continue
                elif l==k:
                    continue
                for p in range(n):
                    if p==i:
                        continue
                    elif p==l:
                        continue
                    elif p==k:
                        continue
                    for r in range(n):
                        if r==p:
                            continue
                        elif r==i:
                            continue
                        elif r==k:
                            continue
                        elif r==l:
                            continue
                        for b in range(n):
                            if b==i:
                                continue
                            elif b==l:
                                continue
                            elif b==k:
                                continue
                            elif b==p:
                                continue
                            elif b==r:
                                continue
                            summe=array_0[i]+array_1[k]+array_2[l]+array_3[p]+array_4[r]+array_5[b]
                            f+=1
                            if summe>best:
                                best_indexes=i, k, l, p, r, b
                                best=summe
                        
    return best_indexes
seas="mjjaso"
area="arc"
data = {'CL1/SCAN': [],
        'CL2/NAO+': [],
        'CL3/NAO-': [],
        'CL4/DIPOL': [],
        'CL5/ATL': [],
        'CL6/': []}
for i in range(len(models)):
    if models[i]=="MULTIMODEL-hist":
        print("choose yourself")
        #years = "historical_mmm_ssp1_1985-2014"
    else:
        if models[i]=="MULTIMODEL-SSP1":
            years="historical_mmm3_2070-2099"
        elif models[i]=="MULTIMODEL-SSP2":
            years="historical_mmm3_2070-2099"
        elif models[i]=="MULTIMODEL-SSP3":
            years="historical_mmm3_2070-2099"
        elif models[i]=="MULTIMODEL-SSP5":
            years="historical_mmm3_2070-2099"
        if area=="paz":
            path_taylor_select_cl1=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Clusternumber-1/taylor_cluster_"+years+".slp_"+seas+".cl1_"+area+".refERA5"
            data_taylor_cl1 = np.loadtxt(path_taylor_select_cl1+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl1 = data_taylor_cl1[1:,1]
            path_taylor_select_cl2=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Clusternumber-2/taylor_cluster_"+years+".slp_"+seas+".cl3_"+area+".refERA5"
            data_taylor_cl2 = np.loadtxt(path_taylor_select_cl2+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl2 = data_taylor_cl2[1:,1]
            path_taylor_select_cl3=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Clusternumber-3/taylor_cluster_"+years+".slp_"+seas+".cl2_"+area+".refERA5"
            data_taylor_cl3 = np.loadtxt(path_taylor_select_cl3+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl3 = data_taylor_cl3[1:,1]
            path_taylor_select_cl4=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Clusternumber-4/taylor_cluster_"+years+".slp_"+seas+".cl5_"+area+".refERA5"
            data_taylor_cl4 = np.loadtxt(path_taylor_select_cl4+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl4 = data_taylor_cl4[1:,1]
            path_taylor_select_cl5=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Clusternumber-5/taylor_cluster_"+years+".slp_"+seas+".cl4_"+area+".refERA5"
            data_taylor_cl5 = np.loadtxt(path_taylor_select_cl5+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl5 = data_taylor_cl5[1:,1]
            argmaxarray = [cor_cl1, cor_cl2, cor_cl3, cor_cl4, cor_cl5]
            maximized_indexes = maximize_sum(argmaxarray)
        elif area=="atl":
            path_taylor_select_cl1=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/SCANURALBlock/taylor_cluster_"+years+".slp_"+seas+".cl1_"+area+".refERA5"
            data_taylor_cl1 = np.loadtxt(path_taylor_select_cl1+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl1 = data_taylor_cl1[1:,1]
            path_taylor_select_cl2=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/NAOPlus/taylor_cluster_"+years+".slp_"+seas+".cl5_"+area+".refERA5"
            data_taylor_cl2 = np.loadtxt(path_taylor_select_cl2+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl2 = data_taylor_cl2[1:,1]
            path_taylor_select_cl3=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/NAOMinus/taylor_cluster_"+years+".slp_"+seas+".cl4_"+area+".refERA5"
            data_taylor_cl3 = np.loadtxt(path_taylor_select_cl3+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl3 = data_taylor_cl3[1:,1]
            path_taylor_select_cl4=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/DipolATLBlock/taylor_cluster_"+years+".slp_"+seas+".cl3_"+area+".refERA5"
            data_taylor_cl4 = np.loadtxt(path_taylor_select_cl4+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl4 = data_taylor_cl4[1:,1]
            path_taylor_select_cl5=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/AtlanticTrough/taylor_cluster_"+years+".slp_"+seas+".cl2_"+area+".refERA5"
            data_taylor_cl5 = np.loadtxt(path_taylor_select_cl5+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl5 = data_taylor_cl5[1:,1]
            argmaxarray = [cor_cl1, cor_cl2, cor_cl3, cor_cl4, cor_cl5]
            maximized_indexes = maximize_sum(argmaxarray)
        elif area=="arc":
            path_taylor_select_cl1=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL1/taylor_cluster_"+years+".slp_"+seas+".cl1_"+area+".refERA5"
            data_taylor_cl1 = np.loadtxt(path_taylor_select_cl1+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl1 = data_taylor_cl1[1:,1]
            path_taylor_select_cl2=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL2/taylor_cluster_"+years+".slp_"+seas+".cl2_"+area+".refERA5"
            data_taylor_cl2 = np.loadtxt(path_taylor_select_cl2+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl2 = data_taylor_cl2[1:,1]
            path_taylor_select_cl3=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL3/taylor_cluster_"+years+".slp_"+seas+".cl3_"+area+".refERA5"
            data_taylor_cl3 = np.loadtxt(path_taylor_select_cl3+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl3 = data_taylor_cl3[1:,1]
            path_taylor_select_cl4=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL4/taylor_cluster_"+years+".slp_"+seas+".cl4_"+area+".refERA5"
            data_taylor_cl4 = np.loadtxt(path_taylor_select_cl4+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl4 = data_taylor_cl4[1:,1]
            path_taylor_select_cl5=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL5/taylor_cluster_"+years+".slp_"+seas+".cl5_"+area+".refERA5"
            data_taylor_cl5 = np.loadtxt(path_taylor_select_cl5+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl5 = data_taylor_cl5[1:,1]
            path_taylor_select_cl6=r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/CL6/taylor_cluster_"+years+".slp_"+seas+".cl3_"+area+".refERA5"
            data_taylor_cl6 = np.loadtxt(path_taylor_select_cl6+models[i]+".txt", skiprows = 2, usecols = range(1,5))
            cor_cl6 = data_taylor_cl6[1:,1]
            argmaxarray = [cor_cl1, cor_cl2, cor_cl3, cor_cl4, cor_cl5, cor_cl6]
            maximized_indexes = maximize_sum(argmaxarray)
        print(models[i]+"mit CL1/SCAN: "+ str(maximized_indexes[0]+1)+"     mit CL2/NAO+: "+ str(maximized_indexes[1]+1)+"     mit CL3/NAO-: "+ str(maximized_indexes[2]+1)+"     mit CL4/DIPOL: "+ str(maximized_indexes[3]+1)+"     mit CL5/ATL: "+ str(maximized_indexes[4]+1)+"     mit CL6/: "+ str(maximized_indexes[5]+1))
        data['CL1/SCAN'].append(maximized_indexes[0]+1)
        data['CL2/NAO+'].append(maximized_indexes[1]+1)
        data['CL3/NAO-'].append(maximized_indexes[2]+1)
        data['CL4/DIPOL'].append(maximized_indexes[3]+1)
        data['CL5/ATL'].append(maximized_indexes[4]+1)
        data['CL6/'].append(maximized_indexes[5]+1)
df = pd.DataFrame(data)
print(df)
# Save the DataFrame to a txt file
df.to_csv('N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_mmm3_'+area+"_"+years+"_"+seas+'.txt', sep='\t', index=False)
# Out:
# choose yourself
# MULTIMODEL-SSP5mit CL1/SCAN: 1     mit CL2/NAO+: 4     mit CL3/NAO-: 3     mit CL4/DIPOL: 2     mit CL5/ATL: 6     mit CL6/: 5
#    CL1/SCAN  CL2/NAO+  CL3/NAO-  CL4/DIPOL  CL5/ATL  CL6/
# 0         1         4         3          2        6     5

# %%
#models = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
   #      "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
    #     "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
     #     "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
import glob
#models = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1",
 #         "GFDL-CM4","GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
  #       "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","MULTIMODEL-hist"]
#models_taylor = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR",
   #       "CNRM-ESM2-1","GFDL-CM4", "GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
    #     "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","MULTIMODEL-hist"]
models = ["ERA5", "SANDRA", "SANDRA","SANDRA", "SANDRA","SANDRA"]
models_taylor = ["ERA5", "CL1", "CL2","CL3","CL4","CL5"]
seas="mjjaso"
namen="CL1"
assigner = 1 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "arc"
cluster="*"
zusatz="historical_mmm3_1985-2014"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5SANDRA.txt") #hier namen
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
cl = {'models' : ["cor", "std", "score1"],
            models_taylor[0]: [1, std_ERA/std_ERA, 1],
            models_taylor[1]: [0, 1, 2],
            models_taylor[2]:[0, 1, 2],
            models_taylor[3]: [0, 1, 2],
            models_taylor[4]: [0, 1, 2],
            models_taylor[5]: [0, 1, 2]
        #    models_taylor[6]: [0, 1, 2],
        }  
print(cl)                
for i in range(1,2):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
      
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_1985-2014"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_paper_"+area+"5_"+zusatz2+"_"+seas+".txt", skiprows=1)[:]
        print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        print(index)
        cl[models_taylor[i]]=[cor[index], std[index], score1[index]]
        print(cl[models_taylor[i]])
        
namen="CL2"
assigner = 2 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "arc"
cluster="*"
zusatz="historical_mmm3_1985-2014"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5SANDRA.txt") #hier namen
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
print(cl)
for i in range(2,3):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_1985-2014"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_paper_"+area+"5_"+zusatz2+"_"+seas+".txt", skiprows=1)[:]
        print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models_taylor[i]]=[cor[index], std[index], score1[index]]
print(cl)        
namen="CL3"
assigner = 3 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "arc"
cluster="*"
zusatz="historical_mmm3_1985-2014"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5SANDRA.txt") #hier namen
for i in range(3,4):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_1985-2014"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_paper_"+area+"5_"+zusatz2+"_"+seas+".txt", skiprows=1)[:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models_taylor[i]]=[cor[index], std[index], score1[index]]
        
namen="CL4"
assigner = 4 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "arc"
cluster="*"
zusatz="historical_mmm3_1985-2014"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5SANDRA.txt") #hier namen
#std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
for i in range(4,5):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_1985-2014"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_paper_"+area+"5_"+zusatz2+"_"+seas+".txt", skiprows=1)[:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models_taylor[i]]=[cor[index], std[index], score1[index]]
        
namen="CL5"
assigner = 5 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "arc"
cluster="*"
zusatz="historical_mmm3_1985-2014"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5SANDRA.txt") #hier namen
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
for i in range(5,6):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_1985-2014"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_paper_"+area+"5_"+zusatz2+"_"+seas+".txt", skiprows=1)[:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models_taylor[i]]=[cor[index], std[index], score1[index]]
# namen="CL6"
# assigner = 6 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
# area = "atl"
# cluster="*"
# zusatz="historical_mmm3_1985-2014"
# path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5SANDRA.txt") #hier namen
# #std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
# for i in range(6,7):
#     if models[i]=="ERA5": #hier VFL.
#         print("ERA5 u need to choose yourself")
        
        
#     else:    
#         add = models[i]
#         path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
#         data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
#         zusatz2="historical_mmm3_1985-2014"
#         assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_paper_"+area+"_"+zusatz2+"_"+seas+".txt", skiprows=1)[:]
#         #print(assignment)
#         #print(data_taylor)
#         cor = data_taylor[:,1]
#         std = data_taylor[:,0]/data_taylor[:,0][0]
#         #print(std)
#         score1 = data_taylor[:,2]
#         #print(cor)
#         #+1 weil python fängt bei null an zzu zählen, 
#         #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
#         index = int(assignment[assigner-1])
#         #print(index)
        cl[models_taylor[i]]=[cor[index], std[index], score1[index]]

        
cl = pd.DataFrame(cl).transpose() 
#print(cl)

#models_taylor = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
     #    "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
      #   "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
       #   "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
std = np.array(list(cl[1][1:]))
cor = np.array(list(cl[0][1:]))
score1 = np.array(list(cl[2][1:]))

import skill_metrics as sm
color1="r"
color2="b"
color3="g"
color4="m"
color5="c"
#color6="y"
MARKERS = {
     models_taylor[1]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color1, "edgeColor": color1,},
      models_taylor[2]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color2, "edgeColor": color2,},
      models_taylor[3]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color3, "edgeColor": color3,},
     models_taylor[4]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color4, "edgeColor": color4,},
        models_taylor[5]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color5, "edgeColor": color5,}
#    models_taylor[6]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color6, "edgeColor": color6,}
}
print(cl)
sm.taylor_diagram(std, score1, cor, titleOBS='Ref', colobs='k', markerlabel=models_taylor, markerlegend='on', 
                  markerobs='X', markersize=15, titleobs='Cluster (KMEANS) as reference     .       .', widthcor=0.5, widthobs=0.3, widthrms=0.3, 
                  widthstd=0.8, styleobs='--', titlerms='off', colRMS='grey', colCOR='black',markers=MARKERS,numberPanels=1)
plt.savefig('N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/'+namen+'/Taylor_Diagram_SANDRA_'+seas+"_"+zusatz+'_10PC_cl5.png',dpi=300,bbox_inches='tight')
# Out:
# {'models': ['cor', 'std', 'score1'], 'ERA5': [1, 1.0, 1], 'CL1': [0, 1, 2], 'CL2': [0, 1, 2], 'CL3': [0, 1, 2], 'CL4': [0, 1, 2], 'CL5': [0, 1, 2]}
# [3. 1. 2. 5. 4.]
# 3
# [0.837, 0.6501560062402496, 0.767]
# {'models': ['cor', 'std', 'score1'], 'ERA5': [1, 1.0, 1], 'CL1': [0.837, 0.6501560062402496, 0.767], 'CL2': [0, 1, 2], 'CL3': [0, 1, 2], 'CL4': [0, 1, 2], 'CL5': [0, 1, 2]}
# [3. 1. 2. 5. 4.]
# {'models': ['cor', 'std', 'score1'], 'ERA5': [1, 1.0, 1], 'CL1': [0.837, 0.6501560062402496, 0.767], 'CL2': [0.802, 1.0306983883346124, 0.9], 'CL3': [0, 1, 2], 'CL4': [0, 1, 2], 'CL5': [0, 1, 2]}
#             0         1       2
# models    cor       std  score1
# ERA5      1.0       1.0     1.0
# CL1     0.837  0.650156   0.767
# CL2     0.802  1.030698     0.9
# CL3     0.861  1.544981   0.775
# CL4     0.777  1.010278   0.888
# CL5     0.743  0.921824   0.866

# %%
#models = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
   #      "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
    #     "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
     #     "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
import glob
#models = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR", "CNRM-ESM2-1",
 #         "GFDL-CM4","GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
  #       "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","MULTIMODEL-hist"]
#models_taylor = ["ERA5","ACCESS-CM2", "ACCESS-ESM1", "CESM2-WACCM", "CNRM-CM6-1", "CNRM-CM6-1-HR",
   #       "CNRM-ESM2-1","GFDL-CM4", "GFDL-ESM4","HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", 
    #     "MPI-ESM1-2-HR", "MPI-ESM1-2-LR", "MRI-ESM2-0", "NorESM2-MM", "UKESM1-0-LL","MULTIMODEL-hist"]
models = ["MULTIMODEL-hist-1", "MULTIMODEL-SSP1-1", "MULTIMODEL-SSP2-1", "MULTIMODEL-SSP3-1", "MULTIMODEL-SSP5-1","MULTIMODEL-SSP1-2", "MULTIMODEL-SSP2-2", "MULTIMODEL-SSP3-2", "MULTIMODEL-SSP5-2", "MULTIMODEL-SSP1-3", "MULTIMODEL-SSP2-3", "MULTIMODEL-SSP3-3", "MULTIMODEL-SSP5-3", "MULTIMODEL-SSP1-4", "MULTIMODEL-SSP2-4", "MULTIMODEL-SSP3-4", "MULTIMODEL-SSP5-4", "MULTIMODEL-SSP1-5", "MULTIMODEL-SSP2-5", "MULTIMODEL-SSP3-5", "MULTIMODEL-SSP5-5"]
models_taylor = ["hist", "SSP1 1", "SSP2 1", "SSP3 1", "SSP5 1","SSP1 2", "SSP2 2", "SSP3 2", "SSP5 2", "SSP1 3", "SSP2 3", "SSP3 3", 
                 "SSP5 3", "SSP1 4", "SSP2 4", "SSP3 4", "SSP5 4", "SSP1 5", "SSP2 5", "SSP3 5", "SSP5 5"]
seas="mjjaso"
namen="Clusternumber-1"
assigner = 1 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "paz"
cluster="*"
zusatz="historical_mmm3_2070-2099"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5MULTIMODEL-SSP1-1.txt") #hier namen
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
cl = {'models' : ["cor", "std", "score1"],
            models[0]: [1, std_ERA/std_ERA, 1],
            models[1]: [0, 1, 2],
            models[2]:[0, 1, 2],
            models[3]: [0, 1, 2],
            models[4]: [0, 1, 2],
            models[5]: [0, 1, 2],
            models[6]: [0, 1, 2],
            models[7]: [0, 1, 2],
            models[8]: [0, 1, 2],
            models[9]: [0, 1, 2],
            models[10]: [0, 1, 2],
            models[11]: [0, 1, 2],
            models[12]: [0, 1, 2],
            models[13]: [0, 1, 2],
            models[14]: [0, 1, 2],
            models[15]: [0, 1, 2],
            models[16]: [0, 1, 2],
            models[17]: [0, 1, 2],
            models[18]: [0, 1, 2],
            models[19]: [0, 1, 2],
            models[20]: [0, 1, 2]}  
print(cl)                
for i in range(1,5):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
      
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_2070-2099"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_mmm3_"+area+"_"+zusatz2+"_"+seas+".txt", skiprows=1)[i-1,:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models[i]]=[cor[index], std[index], score1[index]]
        
namen="Clusternumber-2"
assigner = 2 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "paz"
cluster="*"
zusatz="historical_mmm2_2070-2099"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5MULTIMODEL-SSP1-2.txt") #hier namen
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
print(cl)
for i in range(5,9):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_2070-2099"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_mmm3_"+area+"_"+zusatz2+"_"+seas+".txt", skiprows=1)[i-5,:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models[i]]=[cor[index], std[index], score1[index]]
print(cl)        
namen="Clusternumber-3"
assigner = 3 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "paz"
cluster="*"
zusatz="historical_mmm3_2070-2099"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5MULTIMODEL-SSP1-3.txt") #hier namen
for i in range(9,13):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_2070-2099"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_mmm3_"+area+"_"+zusatz2+"_"+seas+".txt", skiprows=1)[i-9,:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models[i]]=[cor[index], std[index], score1[index]]
        
namen="Clusternumber-4"
assigner = 4 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "paz"
cluster="*"
zusatz="historical_mmm3_2070-2099"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5MULTIMODEL-SSP1-4.txt") #hier namen
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
for i in range(13,17):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_2070-2099"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_mmm3_"+area+"_"+zusatz2+"_"+seas+".txt", skiprows=1)[i-13,:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models[i]]=[cor[index], std[index], score1[index]]
        
namen="Clusternumber-5"
assigner = 5 #scan:1, nao+: 2, nao-: 3, dipol:4, atl:5 # 
area = "paz"
cluster="*"
zusatz="historical_mmm3_2070-2099"
path_taylor_select = glob.glob("N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5MULTIMODEL-SSP1-5.txt") #hier namen
std_ERA=np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))[0,0]
for i in range(17,21):
    if models[i]=="ERA5": #hier VFL.
        print("ERA5 u need to choose yourself")
        
        
    else:    
        add = models[i]
        path_taylor_select = glob.glob(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/"+namen+"/taylor_cluster_"+zusatz+".slp_"+seas+".cl"+cluster+"_"+area+".refERA5"+add+".txt")
        data_taylor = np.loadtxt(path_taylor_select[0], skiprows = 2, usecols = range(1,5))
        zusatz2="historical_mmm3_2070-2099"
        assignment = np.loadtxt(r"N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/Assignment_mmm3_"+area+"_"+zusatz2+"_"+seas+".txt", skiprows=1)[i-17,:]
        #print(assignment)
        #print(data_taylor)
        cor = data_taylor[:,1]
        std = data_taylor[:,0]/data_taylor[:,0][0]
        #print(std)
        score1 = data_taylor[:,2]
        #print(cor)
        #+1 weil python fängt bei null an zzu zählen, 
        #print(assigner)                                                      #   [1:] weil ERA5 mit cor=1 ist immer der 0. wert
        index = int(assignment[assigner-1])
        #print(index)
        cl[models[i]]=[cor[index], std[index], score1[index]]
        
cl = pd.DataFrame(cl).transpose() 
#print(cl)

#models_taylor = ["ERA5", "ACCESS-CM2","ACCESS-ESM1","AWI-ESM-1-1-LR","CESM2","CESM2-FV2","CESM2-WACCM","CESM2-WACCM-FV2",
     #    "CMCC-CM2-HR4","CNRM-CM6-1","CNRM-CM6-1-HR","CNRM-ESM2-1","FGOALS-f3-L","GFDL-CM4","GFDL-ESM4",
      #   "HadGEM3-GC31-LL", "INM-CM4-8", "INM-CM5-0", "IPSL-CM6A-LR", "MIROC6", "MPI-ESM-1-2-HAM", "MPI-ESM1-2-HR", 
       #   "MPI-ESM1-2-LR","MRI-ESM2-0", "NorESM2-MM", "SAM0-UNICON", "UKESM1-0-LL"]
std = np.array(list(cl[1][1:]))
cor = np.array(list(cl[0][1:]))
score1 = np.array(list(cl[2][1:]))

import skill_metrics as sm
color1="r"
color2="b"
color3="c"
color4="m"
color5="g"
MARKERS = {
    models_taylor[1]: { "labelColor": "k", "symbol": "+", "size": 9, "faceColor": color1, "edgeColor": color1,},
   models_taylor[2]: { "labelColor": "k", "symbol": "*", "size": 9, "faceColor": color1, "edgeColor": color1,},
     models_taylor[3]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color1, "edgeColor": color1,},
     models_taylor[4]: { "labelColor": "k", "symbol": "s", "size": 9, "faceColor": color1, "edgeColor": color1,},
      models_taylor[5]: { "labelColor": "k", "symbol": "+", "size": 9, "faceColor": color2, "edgeColor": color2,},
     models_taylor[6]: { "labelColor": "k", "symbol": "*", "size": 9, "faceColor": color2, "edgeColor": color2,},
      models_taylor[7]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color2, "edgeColor": color2,},
      models_taylor[8]: { "labelColor": "k", "symbol": "s", "size": 9, "faceColor": color2, "edgeColor": color2,},
     models_taylor[9]: { "labelColor": "k", "symbol": "+", "size": 9, "faceColor": color3, "edgeColor": color3,},
      models_taylor[10]: { "labelColor": "k", "symbol": "*", "size": 9, "faceColor": color3, "edgeColor": color3,},
     models_taylor[11]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color3, "edgeColor": color3,},
      models_taylor[12]: { "labelColor": "k", "symbol": "s", "size": 9, "faceColor": color3, "edgeColor": color3,},
      models_taylor[13]: { "labelColor": "k", "symbol": "+", "size": 9, "faceColor": color4, "edgeColor": color4,},
     models_taylor[14]: { "labelColor": "k", "symbol": "*", "size": 9, "faceColor": color4, "edgeColor": color4,},
     models_taylor[15]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor":color4, "edgeColor": color4,},
     models_taylor[16]: { "labelColor": "k", "symbol": "s", "size": 9, "faceColor": color4, "edgeColor": color4,},
     models_taylor[17]: { "labelColor": "k", "symbol": "+", "size": 9, "faceColor": color5, "edgeColor": color5,},
     models_taylor[18]: { "labelColor": "k", "symbol": "*", "size": 9, "faceColor": color5, "edgeColor": color5,},
     models_taylor[19]: { "labelColor": "k", "symbol": "x", "size": 9, "faceColor": color5, "edgeColor": color5,},
     models_taylor[20]: { "labelColor": "k", "symbol": "s", "size": 9, "faceColor": color5, "edgeColor": color5,}
}
print(cl)
sm.taylor_diagram(std, score1, cor, titleOBS='Ref', colobs='k', markerlabel=models_taylor, markerlegend='on', 
                  markerobs='x', markersize=10, titleobs='Hist', widthcor=0.5, widthobs=0.3, widthrms=0.3, axisMax=1.5,  
                  widthstd=0.8, styleobs='--', titlerms='off', colRMS='grey', colCOR='black',markers=MARKERS,numberPanels=1)
#lt.show()
plt.savefig('N:/atm_glomod/user/jomuel001/auswertung/TAYLOR/Cluster/'+namen+'/Taylor_Diagram_mmm3_'+seas+"_"+zusatz+'_10PC_cl.png',dpi=300,bbox_inches='tight')
# Out:
# {'models': ['cor', 'std', 'score1'], 'MULTIMODEL-hist-1': [1, 1.0, 1], 'MULTIMODEL-SSP1-1': [0, 1, 2], 'MULTIMODEL-SSP2-1': [0, 1, 2], 'MULTIMODEL-SSP3-1': [0, 1, 2], 'MULTIMODEL-SSP5-1': [0, 1, 2], 'MULTIMODEL-SSP1-2': [0, 1, 2], 'MULTIMODEL-SSP2-2': [0, 1, 2], 'MULTIMODEL-SSP3-2': [0, 1, 2], 'MULTIMODEL-SSP5-2': [0, 1, 2], 'MULTIMODEL-SSP1-3': [0, 1, 2], 'MULTIMODEL-SSP2-3': [0, 1, 2], 'MULTIMODEL-SSP3-3': [0, 1, 2], 'MULTIMODEL-SSP5-3': [0, 1, 2], 'MULTIMODEL-SSP1-4': [0, 1, 2], 'MULTIMODEL-SSP2-4': [0, 1, 2], 'MULTIMODEL-SSP3-4': [0, 1, 2], 'MULTIMODEL-SSP5-4': [0, 1, 2], 'MULTIMODEL-SSP1-5': [0, 1, 2], 'MULTIMODEL-SSP2-5': [0, 1, 2], 'MULTIMODEL-SSP3-5': [0, 1, 2], 'MULTIMODEL-SSP5-5': [0, 1, 2]}
# ...
